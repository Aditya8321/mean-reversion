# %% [markdown]
# # 01 - Data Collection
# This notebook downloads historical stock data for our mean-reversion pairs and cleans it for analysis.

# %%
import yfinance as yf
import pandas as pd
import os

# %%
# Download data
tickers = ["KO", "MCD"]
data = yf.download(tickers, start="2010-01-01", end="2025-01-01")['Close']

# Fill missing values
data = data.ffill().bfill()
# Out:
# /var/folders/bv/q79dnkgx31j62rs4kyg5rwpm0000gn/T/ipykernel_45009/1619115150.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers, start="2010-01-01", end="2025-01-01")['Close']
# [*********************100%***********************]  2 of 2 completed

# %%
os.makedirs("../data/raw_prices", exist_ok=True)
os.makedirs("../data/processed", exist_ok=True)

# %%
# Save raw and processed data
data.to_csv("../data/raw_prices/ko_mcd.csv")
data.to_csv("../data/processed/ko_mcd_clean.csv")

# Plot prices
import matplotlib.pyplot as plt
data.plot(figsize=(12,6), title="KO vs MCD Prices")
plt.show()
